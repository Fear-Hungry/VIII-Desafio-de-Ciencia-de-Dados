# %%
# !pip install openbb polars
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.8/34.8 MB 12.2 MB/s eta 0:00:0000:0100:01
# ...

# %%
from openbb import obb
import pandas as pd
import polars as pl

# %%
hist = obb.equity.price.historical('AAPL', start_date='2020-01-01', end_date='2023-01-01', provider='yfinance', interval='1d').to_dataframe()
df = pl.from_pandas(hist)
df
# Out:
# shape: (756, 7)
# ┌────────────┬────────────┬────────────┬────────────┬───────────┬─────────────┬──────────┐
# │ open       ┆ high       ┆ low        ┆ close      ┆ volume    ┆ split_ratio ┆ dividend │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---         ┆ ---      │
# │ f64        ┆ f64        ┆ f64        ┆ f64        ┆ i64       ┆ f64         ┆ f64      │
# ╞════════════╪════════════╪════════════╪════════════╪═══════════╪═════════════╪══════════╡
# │ 74.059998  ┆ 75.150002  ┆ 73.797501  ┆ 75.087502  ┆ 135480400 ┆ 0.0         ┆ 0.0      │
# │ 74.287498  ┆ 75.144997  ┆ 74.125     ┆ 74.357498  ┆ 146322800 ┆ 0.0         ┆ 0.0      │
# │ 73.447502  ┆ 74.989998  ┆ 73.1875    ┆ 74.949997  ┆ 118387200 ┆ 0.0         ┆ 0.0      │
# │ 74.959999  ┆ 75.224998  ┆ 74.370003  ┆ 74.597504  ┆ 108872000 ┆ 0.0         ┆ 0.0      │
# │ 74.290001  ┆ 76.110001  ┆ 74.290001  ┆ 75.797501  ┆ 132079200 ┆ 0.0         ┆ 0.0      │
# ...
