# %%
#instalando a biblioteca
# !pip install alpha_vantage

# %%
# chamando as biblotecas
from alpha_vantage.timeseries import TimeSeries
import requests
import pandas as pd
import json

api_key = 'suachave'
symbol = 'AAPL'
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=AAPL&apikey=suachave'
r = requests.get(url)

# %%
data = r.json()['Time Series (5min)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-a7f54f03e9bf> in <cell line: 0>()
# ----> 1 data = r.json()['Time Series (5min)']
#
# KeyError: 'Time Series (5min)'

# %%
#Importando os dados temporais mensais para um Data Frame
df = data

#Renomiando as colunas e organizando os tipos de dados das colunas
df = pd.DataFrame(data).T.reset_index()
df.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
df = df.astype({'Date': 'datetime64[ns]', 'Open': 'float', 'High': 'float', 'Low': 'float', 'Close': 'float', 'Volume': 'float'})
df
# Out:
#           Date     Open      High       Low   Close        Volume
# 0   2025-04-25  219.805  225.1900  169.2101  209.28  1.479461e+09
# 1   2025-03-31  241.790  244.0272  208.4200  222.13  1.114686e+09
# 2   2025-02-28  229.990  250.0000  225.7000  241.84  8.623170e+08
# 3   2025-01-31  248.930  249.1000  219.3800  236.00  1.200292e+09
# 4   2024-12-31  237.270  260.1000  237.1600  250.42  9.779420e+08
# ..         ...      ...       ...       ...     ...           ...
# 300 2000-04-28  135.500  139.5000  104.8700  124.06  7.734290e+07
# 301 2000-03-31  118.560  150.3800  114.0000  135.81  7.766390e+07
# 302 2000-02-29  104.000  119.9400   97.0000  114.62  6.535520e+07
# 303 2000-01-31  104.870  121.5000   86.5000  103.75  1.120998e+08
# 304 1999-12-31  101.000  118.0000   91.0600  102.81  8.409120e+07
#
# [305 rows x 6 columns]
